# %% [markdown]
# # **DDC-11: Subplots with gridspec**
# Use the gridspec module in matplotlib to create a figure like the one below. The data are all random numbers; the main focus here is setting up the axes.
# <p align="center">
#   <img src="images/img_ddc_011.png" alt="011" width="400">
# </p>

# %%
# Libs

import numpy as np
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt

plt.style.use("dark_background")

# %%
fig = plt.figure(figsize=(8,5))

gs = GridSpec(2,2)
ax0 = fig.add_subplot(gs[:,0])
ax1 = fig.add_subplot(gs[0,1])
ax2 = fig.add_subplot(gs[1,1])

ax0.imshow(np.random.randn(50,31))

ax1.plot(np.random.randn(10,5))

ax2.plot(np.random.randn(5,10))

plt.tight_layout()
plt.show()
